# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("temperature_forescating.csv")
data.head()
# Out:
#        DATE  MinTemp  MaxTemp  AvgTemp  Sunrise  Sunset
# 0  1/1/2014     33.0     46.0     40.0      657    1756
# 1  1/2/2014     35.0     50.0     43.0      657    1756
# 2  1/3/2014     36.0     45.0     41.0      657    1757
# 3  1/4/2014     32.0     41.0     37.0      658    1757
# 4  1/5/2014     24.0     38.0     31.0      658    1758

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     1825 non-null   object
#  1   MinTemp  1821 non-null   float64
#  2   MaxTemp  1821 non-null   float64
#  3   AvgTemp  1821 non-null   float64
#  4   Sunrise  1825 non-null   int64
#  5   Sunset   1825 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 85.7+ KB

# %%
data['DATE']=pd.to_datetime(data['DATE'])
data.info
# Out:
# <bound method DataFrame.info of            DATE  MinTemp  MaxTemp  AvgTemp  Sunrise  Sunset
# 0    2014-01-01     33.0     46.0     40.0      657    1756
# 1    2014-01-02     35.0     50.0     43.0      657    1756
# 2    2014-01-03     36.0     45.0     41.0      657    1757
# 3    2014-01-04     32.0     41.0     37.0      658    1757
# 4    2014-01-05     24.0     38.0     31.0      658    1758
# ...         ...      ...      ...      ...      ...     ...
# 1820 2018-12-26     35.0     45.0     40.0      654    1752
# 1821 2018-12-27     33.0     44.0     39.0      655    1752
# 1822 2018-12-28     33.0     47.0     40.0      655    1753
# 1823 2018-12-29     36.0     47.0     42.0      655    1753
# 1824 2018-12-30     39.0     52.0     46.0      656    1754
#
# [1825 rows x 6 columns]>

# %%
data.isna().sum()
# Out:
# DATE       0
# MinTemp    4
# MaxTemp    4
# AvgTemp    4
# Sunrise    0
# Sunset     0
# dtype: int64

# %%
data=data.dropna()
data.isna().sum()
# Out:
# DATE       0
# MinTemp    0
# MaxTemp    0
# AvgTemp    0
# Sunrise    0
# Sunset     0
# dtype: int64

# %%
data.head()
# Out:
#         DATE  MinTemp  MaxTemp  AvgTemp  Sunrise  Sunset
# 0 2014-01-01     33.0     46.0     40.0      657    1756
# 1 2014-01-02     35.0     50.0     43.0      657    1756
# 2 2014-01-03     36.0     45.0     41.0      657    1757
# 3 2014-01-04     32.0     41.0     37.0      658    1757
# 4 2014-01-05     24.0     38.0     31.0      658    1758

# %%
data['Year']=data['DATE'].dt.year
data['Month']=data['DATE'].dt.month
# Out:
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.head()
# Out:
#         DATE  MinTemp  MaxTemp  AvgTemp  Sunrise  Sunset  Year  Month
# 0 2014-01-01     33.0     46.0     40.0      657    1756  2014      1
# 1 2014-01-02     35.0     50.0     43.0      657    1756  2014      1
# 2 2014-01-03     36.0     45.0     41.0      657    1757  2014      1
# 3 2014-01-04     32.0     41.0     37.0      658    1757  2014      1
# 4 2014-01-05     24.0     38.0     31.0      658    1758  2014      1

# %%
def plot_vars(data,x,y,year):
    fig,ax=plt.subplots(figsize=(20,10))
    sns.lineplot(
    ax=ax,
    data=data,
    x=x,
    y=y,
    hue=year,
    palette='bright'
        )
    plt.show()

# %%
plot_vars(data,'DATE','AvgTemp','Year')

# %%
plot_vars(data,'DATE','MinTemp','Year')

# %%
plot_vars(data,'DATE','MaxTemp','Year')

# %%
plot_vars(data,'DATE','Sunrise','Year')

# %%
plot_vars(data,'DATE','Sunset','Year')

# %% [markdown]
# # Exploring the temperature change over years each month

# %%
def plot_change(data,x,y,year):
    fig,ax = plt.subplots(figsize=(20,10))
    sns.lineplot(
    ax=ax,
    data=data,
    x=x,
    y=y,
    hue=year,
    palette='bright'
        )
    plt.show()

# %%
plot_change(data,'Month','AvgTemp','Year')

# %%
plot_change(data,'Month','MinTemp','Year')

# %%
plot_change(data,'Month','MaxTemp','Year')

# %%
plot_change(data,'Month','Sunrise','Year')

# %%
plot_change(data,'Month','Sunset','Year')

# %% [markdown]
# # Exploring the relatioship between Avg Temp and Sunrise

# %%
def rel_temp(data,x,y):
    fig,ax = plt.subplots(figsize=(20,10))
    sns.scatterplot(
    ax=ax,
    data=data,
    x=x,
    y=y,
    palette='flare',
    size=y,
    hue=y
    )
    plt.show()

# %%
rel_temp(data,'AvgTemp','Sunset')

# %%
data.corr()
# Out:
#           MinTemp   MaxTemp   AvgTemp   Sunrise    Sunset      Year     Month
# MinTemp  1.000000  0.756071  0.917456 -0.426821  0.300492  0.008075  0.227415
# MaxTemp  0.756071  1.000000  0.951039 -0.374928  0.275876 -0.029029  0.137562
# AvgTemp  0.917456  0.951039  1.000000 -0.422829  0.304711 -0.015718  0.186884
# Sunrise -0.426821 -0.374928 -0.422829  1.000000 -0.739777 -0.002254 -0.049908
# Sunset   0.300492  0.275876  0.304711 -0.739777  1.000000  0.002415 -0.415416
# Year     0.008075 -0.029029 -0.015718 -0.002254  0.002415  1.000000 -0.002077
# Month    0.227415  0.137562  0.186884 -0.049908 -0.415416 -0.002077  1.000000

# %%
forecast_data=data.rename(columns={'DATE':'ds','AvgTemp':'y'})
forecast_data.head()
# Out:
#           ds  MinTemp  MaxTemp     y  Sunrise  Sunset  Year  Month
# 0 2014-01-01     33.0     46.0  40.0      657    1756  2014      1
# 1 2014-01-02     35.0     50.0  43.0      657    1756  2014      1
# 2 2014-01-03     36.0     45.0  41.0      657    1757  2014      1
# 3 2014-01-04     32.0     41.0  37.0      658    1757  2014      1
# 4 2014-01-05     24.0     38.0  31.0      658    1758  2014      1

# %%
ndata=data

# %%
ndata.head()
# Out:
#         DATE  MinTemp  MaxTemp  AvgTemp  Sunrise  Sunset  Year  Month
# 0 2014-01-01     33.0     46.0     40.0      657    1756  2014      1
# 1 2014-01-02     35.0     50.0     43.0      657    1756  2014      1
# 2 2014-01-03     36.0     45.0     41.0      657    1757  2014      1
# 3 2014-01-04     32.0     41.0     37.0      658    1757  2014      1
# 4 2014-01-05     24.0     38.0     31.0      658    1758  2014      1

# %% [markdown]
# # ARIMA Model

# %%
ndata=ndata.drop(columns=['MinTemp','MaxTemp','Sunrise','Sunset','Year','Month'])

# %%
ndata=ndata.set_index('DATE')

# %%
ndata.head()
# Out:
#             AvgTemp
# DATE
# 2014-01-01     40.0
# 2014-01-02     43.0
# 2014-01-03     41.0
# 2014-01-04     37.0
# 2014-01-05     31.0

# %%
plt.figure(figsize=(20,10))
ndata.AvgTemp.plot(title='Temperature',fontsize=14,color='salmon')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(ndata):
    ndatatest = adfuller(ndata,autolag='AIC')
    print("1.ADF:",ndatatest[0])
    print("2.p-Value:",ndatatest[1])
    print("3.Num Of Lags:",ndatatest[2])
    print("4.Num Of Observation Used For ADF Regression:",ndatatest[3])
    print("5.Critical Values:")
    for key,val in ndatatest[4].items():
        print("\t",key,": ",val)
adf_test(ndata['AvgTemp'])
# Out:
# 1.ADF: -6.554680125068782
# 2.p-Value: 8.675937480199415e-09
# 3.Num Of Lags: 12
# 4.Num Of Observation Used For ADF Regression: 1808
# 5.Critical Values:
# 	 1% :  -3.433972018026501
# 	 5% :  -2.8631399192826676
# 	 10% :  -2.5676217442756872

# %%
#pip install pmdarima

# %%
from pmdarima import auto_arima
arimadata = auto_arima(ndata['AvgTemp'], trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=8344.074, Time=3.30 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=10347.755, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=8365.701, Time=0.37 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=9136.225, Time=0.39 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=19192.139, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=8355.947, Time=2.58 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=8356.308, Time=2.52 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=8347.322, Time=2.92 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=8318.570, Time=2.98 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=8330.189, Time=3.38 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=8312.273, Time=3.99 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=8331.975, Time=4.36 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=8317.568, Time=4.21 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=8308.024, Time=3.64 sec
# ...

# %%
import statsmodels.api as sm

# %%
train=ndata.iloc[:-30]
test=ndata.iloc[-30:]
print(train.shape,test.shape)
print(ndata.shape)
# Out:
# (1791, 1) (30, 1)
# (1821, 1)

# %%
model=sm.tsa.arima.ARIMA(train['AvgTemp'],order=(1,0,5))
model=model.fit()
model.summary()
# Out:
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                AvgTemp   No. Observations:                 1791
# ...

# %%
start=len(train)
end=len(train)+len(test)-1
pred=model.predict(start=start,end=end,typ='levels').rename('ARIMA Predictions')
pred.index=ndata.index[start:end+1]
print(pred)
pred.dtypes
# Out:
# DATE
# 2018-12-01    44.754109
# 2018-12-02    44.987795
# 2018-12-03    45.388741
# 2018-12-04    45.721545
# 2018-12-05    45.863733
# 2018-12-06    45.874126
# 2018-12-07    45.884370
# 2018-12-08    45.894466
# 2018-12-09    45.904417
# 2018-12-10    45.914225
# 2018-12-11    45.923891
# 2018-12-12    45.933418
# 2018-12-13    45.942808
# 2018-12-14    45.952063
# 2018-12-15    45.961185
# 2018-12-16    45.970175
# 2018-12-17    45.979036
# 2018-12-18    45.987769
# 2018-12-19    45.996377
# 2018-12-20    46.004861
# 2018-12-21    46.013222
# 2018-12-22    46.021463
# 2018-12-23    46.029586
# 2018-12-24    46.037591
# 2018-12-25    46.045481
# 2018-12-26    46.053258
# 2018-12-27    46.060923
# 2018-12-28    46.068477
# 2018-12-29    46.075922
# 2018-12-30    46.083261
# Name: ARIMA Predictions, dtype: float64
# ...

# %%
pred.plot(legend=True)
test['AvgTemp'].plot(legend=True)

# %%
test['AvgTemp'].mean()
# Out:
# 45.0

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse=sqrt(mean_squared_error(pred,test['AvgTemp']))
rmse
# Out:
# 3.0004638198463107

# %%
model2=sm.tsa.arima.ARIMA(ndata['AvgTemp'],order=(1,0,5))
model2=model2.fit()
# Out:
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
index_future_dates=pd.date_range(start="2024-06-15",end="2024-07-15")
print(index_future_dates)
# Out:
# DatetimeIndex(['2024-06-15', '2024-06-16', '2024-06-17', '2024-06-18',
#                '2024-06-19', '2024-06-20', '2024-06-21', '2024-06-22',
#                '2024-06-23', '2024-06-24', '2024-06-25', '2024-06-26',
#                '2024-06-27', '2024-06-28', '2024-06-29', '2024-06-30',
#                '2024-07-01', '2024-07-02', '2024-07-03', '2024-07-04',
#                '2024-07-05', '2024-07-06', '2024-07-07', '2024-07-08',
#                '2024-07-09', '2024-07-10', '2024-07-11', '2024-07-12',
#                '2024-07-13', '2024-07-14', '2024-07-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
pred=model2.predict(start=len(ndata),end=len(ndata)+30,types="levels").rename("Arima Prediction")
pred.index=index_future_dates
pred
# Out:
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# 2024-06-15    46.418166
# 2024-06-16    46.113912
# 2024-06-17    45.617874
# 2024-06-18    45.249566
# 2024-06-19    45.116916
# 2024-06-20    45.136666
# 2024-06-21    45.156140
# 2024-06-22    45.175342
# 2024-06-23    45.194275
# 2024-06-24    45.212943
# 2024-06-25    45.231350
# 2024-06-26    45.249499
# 2024-06-27    45.267394
# 2024-06-28    45.285039
# 2024-06-29    45.302437
# 2024-06-30    45.319592
# 2024-07-01    45.336506
# 2024-07-02    45.353184
# 2024-07-03    45.369629
# 2024-07-04    45.385843
# 2024-07-05    45.401831
# 2024-07-06    45.417595
# 2024-07-07    45.433138
# 2024-07-08    45.448464
# 2024-07-09    45.463575
# 2024-07-10    45.478475
# 2024-07-11    45.493167
# 2024-07-12    45.507652
# 2024-07-13    45.521936
# ...

# %%
pred.plot(figsize=(12,5),legend=True)
